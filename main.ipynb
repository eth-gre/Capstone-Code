# %%
import pandas as pd

# %%
df = pd.read_csv('data/upd4_hh_b.csv')
# Out:
# /var/folders/9x/qwl41gr945d41fk57f4wdjq80000gn/T/ipykernel_52539/1086604303.py:1: DtypeWarning: Columns (0: hb_21_3, 1: hb_21_4, 2: hb_23_3, 3: hb_23_4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/upd4_hh_b.csv')

# %%
df['hb_23_1'].describe()
# Out:
# count    24706.00000
# mean         1.90140
# std          1.96457
# min          1.00000
# 25%          1.00000
# 50%          2.00000
# 75%          2.00000
# max         52.00000
# Name: hb_23_1, dtype: float64
